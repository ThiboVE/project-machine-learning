# %%
from rdkit.Chem import Draw, Descriptors, Descriptors3D
from rdkit import Chem

# %%
# Path to your SDF file
sdf_file = "data/QM9/raw/gdb9.sdf"

# Create a supplier to read the SDF
supplier = Chem.SDMolSupplier(sdf_file)

mol = supplier[35015]

print(dir(mol.GetAtoms()))
print(mol.GetAtoms())

# Iterate through molecules
# for mol in supplier:
#     if mol is None:
#         continue  # skip invalid entries
#     print(mol.GetNumAtoms(), mol.GetProp("_Name"))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_getRDKitItem', '_mol', '_pos', '_size', '_sizeCalc']
# ...

# %%
img = Draw.MolToImage(mol, size=(400, 300))
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x300>

# %%
Descriptors.CalcMolDescriptors(mol)
# Out:
# {'MaxAbsEStateIndex': np.float64(5.250138888888889),
#  'MaxEStateIndex': np.float64(5.250138888888889),
#  'MinAbsEStateIndex': np.float64(0.03298611111111116),
#  'MinEStateIndex': np.float64(-0.03298611111111116),
#  'qed': 0.4146812051004916,
#  'SPS': 51.77777777777778,
#  'MolWt': 118.13499999999999,
#  'HeavyAtomMolWt': 112.08699999999997,
#  'ExactMolWt': 118.041864812,
#  'NumValenceElectrons': 44,
#  'NumRadicalElectrons': 0,
#  'MaxPartialCharge': 0.09801820533364777,
#  'MinPartialCharge': -0.3734043046843908,
#  'MaxAbsPartialCharge': 0.3734043046843908,
#  'MinAbsPartialCharge': 0.09801820533364777,
#  'FpDensityMorgan1': 1.5555555555555556,
#  'FpDensityMorgan2': 2.3333333333333335,
#  'FpDensityMorgan3': 2.4444444444444446,
#  'BCUT2D_MWHI': 16.528983147447413,
#  'BCUT2D_MWLOW': 10.04912524940108,
#  'BCUT2D_CHGHI': 2.7175154385487503,
#  'BCUT2D_CHGLO': -2.17691893398201,
#  'BCUT2D_LOGPHI': 2.6103458876569654,
#  'BCUT2D_LOGPLOW': -2.2515281550367647,
# ...
